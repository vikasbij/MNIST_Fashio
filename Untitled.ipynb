# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

# %%
img =cv.imread('images.png')
img = cv.resize(img,(100,100))

# %%
img.shape
# Out:
# (100, 100, 3)

# %%
a = np.array([[ 0, 1, 0], 
                   [ 1, -4, 1], 
                   [ 0, 1, 0]])

# %%
a
# Out:
# array([[ 0,  1,  0],
#        [ 1, -4,  1],
#        [ 0,  1,  0]])

# %%
gray = cv.cvtColor(img, cv.COLOR_RGB2GRAY)
print(gray.shape)
print(a.shape)
out = cv.filter2D(gray,-1,a)
# Out:
# (100, 100)
# (3, 3)

# %%
plt.imshow(out, cmap='Greys_r')
